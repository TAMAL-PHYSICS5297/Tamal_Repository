# %% [markdown]
# <a href="https://colab.research.google.com/github/TAMAL-PHYSICS5297/Tamal_Repository/blob/main/Split_Dataset_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_excel("Salary_Dataset_02.xls")
df.head()


X = df.iloc[:,:-1]
y = df.iloc[:,-1]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state = 90)

# %%
X_train
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience
# 29          0       1      0    0  121872             10.5
# 6           0       1      0    0   60150              3.0
# 20          0       1      0    0   91738              6.8
# 23          1       0      0    0  113812              8.2
# 25          1       0      0    0  105582              9.0
# 14          1       0      0    0   61111              4.5
# 8           0       0      1    0   64445              3.2
# 22          1       0      0    0  101302              7.9
# 15          0       0      0    1   67938              4.9
# 21          1       0      0    0   98273              7.1
# 9           0       0      1    0   57189              3.7
# 13          0       1      0    0   57081              4.1
# 16          0       0      0    1   66029              5.1
# 19          0       1      0    0   93940              6.0
# 11          0       0      0    1   55794              4.0
# ...

# %%
X_test
# Out:
#     Australia  Canada  Dubai  USA  Salary  YearsExperience
# 17          0       1      0    0   83088              5.3
# 24          0       0      1    0  109431              8.7
# 26          0       0      1    0  116969              9.5
# 2           0       1      0    0   37731              1.5
# 1           0       1      0    0   46205              1.3
# 12          0       0      1    0   56957              4.0

# %%
y_train
# Out:
# 29    1
# 6     1
# 20    0
# 23    1
# 25    1
# 14    0
# 8     1
# 22    0
# 15    0
# 21    0
# 9     0
# 13    0
# 16    0
# 19    0
# 11    0
# 0     0
# 10    1
# 28    0
# 5     0
# 4     0
# 7     0
# 3     0
# 18    1
# 27    1
# Name: Purchased, dtype: int64

# %%
y_test
# Out:
# 17    0
# 24    0
# 26    0
# 2     0
# 1     1
# 12    1
# Name: Purchased, dtype: int64
